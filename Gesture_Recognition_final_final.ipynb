# %% [markdown]
# # Gesture Recognition
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started.

# %%
import numpy as np
import os
#from scipy.misc import imread, imresize
import datetime
import os
from PIL import Image, ImageFilter, ImageEnhance
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
import imageio
import PIL.Image as img

# %%
# from scipy.ndimage import zoom

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !unzip Project_data.zip

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
import os
os.environ['PYTHONHASHSEED']="30"
np.random.seed(30)
import random as rn
rn.seed(30)
import tensorflow as tf
tf.random.set_seed(30)
from keras import backend as K

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
# train and validatiaon data creator with ablation
# when ablation is 10, then 10 folders for each label will be selected.
def get_data(path, ablation=None):
    train_doc = np.random.permutation(open(path+'train.csv').readlines())
    val_doc = np.random.permutation(open(path+'val.csv').readlines())
    counts = np.zeros(5) # count for loading folders for 5 classes
    train_data = []
    val_data = []
    # when ablation is None pass full training and val data
    if ablation is not None:
        # iterating train doc
        for doc in train_doc:
            lable = int(doc.strip().split(';')[2])
            if counts[lable] < ablation:
                train_data.append(doc)
                counts[lable] += 1 
        counts = np.zeros(5)
        # iterating val doc
        for doc in val_doc:
            lable = int(doc.strip().split(';')[2])
            if counts[lable] < ablation:
                val_data.append(doc)
                counts[lable] += 1
    else:
        train_data, val_data = train_doc, val_doc
    return train_data, val_data

# %%
train_doc, val_doc = get_data('/content/drive/MyDrive/Project_data/', ablation=None)
batch_size = 64 # experiment with the batch size
enable_augmentation = False # augmentation of Data
# sequence ids
# selecting alternate frames from 7 to 26.
seq_idx = range(7,26,2)
# image dimensions
dim_x, dim_y = 120, 120

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
# generator with augmentation for train data
def generator(source_path, folder_list, batch_size, is_train = False, augmention = False, debug=False):
    # print('\nSource path = ', source_path, '; batch size =', batch_size)
    img_idx = seq_idx #create a list of image numbers you want to use for a particular video
    x = len(img_idx)
    y, z = dim_x, dim_y
    while True:
        # doubling the data for augmentation
        if is_train and augmention:
            t = np.concatenate((np.random.permutation(folder_list), np.random.permutation(folder_list)))
        else:
            t = np.random.permutation(folder_list)
            
        if (len(t)%batch_size) == 0:
            num_batches = int(len(t)/batch_size)
        else:
            num_batches = len(t)//batch_size + 1
            
        for batch in range(num_batches): # we iterate over the number of batches
            batch_data = np.zeros((batch_size,x,y,z,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                if debug:
                    plt.figure(figsize=(20,5))
                #handling remaining datapoints
                folder_idx = folder + (batch*batch_size)
                if folder_idx >= len(t):
                    break
                folder_str = t[folder_idx]
                imgs = os.listdir(source_path+'/'+ folder_str.split(';')[0]) # read all the images in the folder
                # randomly enabling augmentation and augmentation type
                aug_type = None
                if is_train and augmention and rn.randint(0,1) == 1:
                    aug_type = rn.randint(0, 4) #randomly selecting augmentation type
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    #print(source_path+'/'+ folder_str.strip().split(';')[0]+'/'+imgs[item])
             #       print('item',item, 'length_images', len(imgs))
                    if item >= len(imgs):
                      continue
              #       print('source path and folder str',source_path, folder_str)
              #       print('item',item)
              #       print('image_name',imgs[item])
              #       print('\n')

                    image = imageio.imread(source_path+'/'+ folder_str.strip().split(';')[0]+'/'+imgs[item])#.astype(np.float32)
                    # plotting original images for debugging purpose only
                    if debug:
                        plt.subplot(2, x, idx+1)
                        plt.imshow(image.astype('uint8'))

                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    # making the rectangle images into square by cropping sides
                    # so the aspect ration can be mantained while resizing.
                    if image.shape[1] > image.shape[0]:
                        diff_px = image.shape[1] - image.shape[0]
                        crop_start = diff_px//2
                        crop_end = crop_start + image.shape[0]
                        image = image[:, crop_start:crop_end]
                    elif image.shape[0] > image.shape[1]:
                        diff_px = image.shape[0] - image.shape[1]
                        crop_start = diff_px//2
                        crop_end = crop_start + image.shape[1]
                        image = image[:, crop_start:crop_end]

                  #  resized_im = image.resize((y,z))
                 #   print('old',image.shape)
                    resized_im = np.resize(image, (y,z,3))
                  #  print('new',resized_im.shape)


                    if aug_type is not None:
                        if aug_type == 0: # edge Enhancement
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.EDGE_ENHANCE))
                        elif aug_type == 1: # adding gaussian blur
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.GaussianBlur(1)))
                        elif aug_type == 2: # enchancing image detailing
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.DETAIL))
                        elif aug_type == 3: # sharpening image
                            resized_im = np.array(Image.fromarray(resized_im, 'RGB').filter(ImageFilter.SHARPEN))
                        elif aug_type == 4: # Brightness enhancement
                            resized_im = np.array(ImageEnhance.Brightness((Image.fromarray(resized_im, 'RGB'))).enhance(1.5))
                    # plotting rezised images for debugging purpose only
                    if debug:
                        plt.subplot(2, x, idx+x+1)
                        plt.imshow(resized_im)

                    batch_data[folder,idx,:,:,0] = resized_im[:,:,0]/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = resized_im[:,:,1]/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = resized_im[:,:,2]/255 #normalise and feed in the image

                batch_labels[folder, int(folder_str.strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
train_path = 'Project_data/train' #'/notebooks/storage/Final_data/Collated_training/train'
val_path =  'Project_data/val' #'/notebooks/storage/Final_data/Collated_training/val'

#multiply number train seq by 2 when using augmentation
multiplier = 1
if enable_augmentation:
    multiplier = 2
num_train_sequences = len(train_doc)*multiplier
print('# training sequences =', num_train_sequences)

num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)

num_epochs = 50 # choose the number of epochs
print('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 50

# %%
# testing generative 
test_gen = generator(train_path, train_doc, 1, is_train = True, augmention = True, debug = True)
d = next(test_gen)[0]
d.shape
# Out:
# (1, 10, 120, 120, 3)

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Bidirectional, BatchNormalization, Activation, Dropout, GlobalAveragePooling2D, GlobalAveragePooling3D, ConvLSTM2D
from keras.layers.convolutional import Conv2D, Conv3D, MaxPooling2D, MaxPooling3D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers

#input shape for the st layer
input_shape = (len(seq_idx), dim_x, dim_y, 3)
np.random.seed(30)

# %% [markdown]
# ### Experiment - 1 & 2
# **Conv3D**

# %%
# model = Sequential()
# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(MaxPooling3D(pool_size=2))

# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=2))

# model.add(Flatten())
# model.add(Dense(256, activation='relu'))
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 3
# **Conv3D**

# %%
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))

# model.add(Conv3D(256, kernel_size=(3, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(3, 2, 2)))

# model.add(Conv3D(512, kernel_size=(3, 3, 3), activation='relu'))
# model.add(Conv3D(512, kernel_size=(3, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))

# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 4
# **Conv3D**

# %%
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))

# model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))

# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))

# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 5 & 6
# **Conv3D**

# %%
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))
# model.add(BatchNormalization())

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())

# model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())

# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())

# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# ### Experiment - 7 & 8
# **Conv3D**

# %%
# model = Sequential()

# model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
# model.add(Conv3D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(2, 2, 2)))
# model.add(BatchNormalization())
# #model.add(Dropout(0.2))
# model.add(Dropout(0.5))

# model.add(Conv3D(128, kernel_size=3, activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# #model.add(Dropout(0.2))
# model.add(Dropout(0.5))

# model.add(Conv3D(256, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# #model.add(Dropout(0.2))
# model.add(Dropout(0.5))

# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(Conv3D(512, kernel_size=(1, 3, 3), activation='relu'))
# model.add(MaxPooling3D(pool_size=(1, 2, 2)))
# model.add(BatchNormalization())
# #model.add(Dropout(0.2))
# model.add(Dropout(0.5))

# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dense(5, activation='softmax'))

# %% [markdown]
# # Final Model

# %%
model = Sequential()
model.add(TimeDistributed(
    Conv2D(8, (3,3), activation='relu'), input_shape=input_shape)
)
model.add(BatchNormalization())
model.add(TimeDistributed(
    Conv2D(16, (3,3), activation='relu'))
)
model.add(BatchNormalization())
model.add(
    ConvLSTM2D(8, kernel_size = 3, return_sequences=False)
)
model.add(BatchNormalization())
model.add(TimeDistributed(
    Dense(64, activation='relu'))
)
model.add(BatchNormalization())
model.add(GlobalAveragePooling2D())
model.add(Dense(64, activation='relu'))
model.add(Dense(5, activation='softmax'))

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %%
optimiser = optimizers.Adam(lr=0.01) #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDistr  (None, 10, 118, 118, 8)  224
#  ibuted)
#
#  batch_normalization (BatchN  (None, 10, 118, 118, 8)  32
#  ormalization)
#
#  time_distributed_1 (TimeDis  (None, 10, 116, 116, 16)  1168
#  tributed)
#
#  batch_normalization_1 (Batc  (None, 10, 116, 116, 16)  64
#  hNormalization)
#
#  conv_lstm2d (ConvLSTM2D)    (None, 114, 114, 8)       6944
#
#  batch_normalization_2 (Batc  (None, 114, 114, 8)      32
#  hNormalization)
#
#  time_distributed_2 (TimeDis  (None, 114, 114, 64)     576
#  tributed)
#
#  batch_normalization_3 (Batc  (None, 114, 114, 64)     256
#  hNormalization)
#
#  global_average_pooling2d (G  (None, 64)               0
#  lobalAveragePooling2D)
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 13,781
# Trainable params: 13,589
# Non-trainable params: 192
# _________________________________________________________________
# None

# %% [markdown]
# Let us create the `train_generator` and the `val_generator` which will be used in `.fit_generator`.

# %%
train_generator = generator(train_path, train_doc, batch_size, is_train = True, augmention = enable_augmentation)
val_generator = generator(val_path, val_doc, batch_size)

# %%
model_name = 'model_init_exp_16' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'

if not os.path.exists(model_name):
    os.mkdir(model_name)

filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.001, verbose=1) # write the REducelronplateau code here

callbacks_list = [checkpoint, LR]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                        callbacks=callbacks_list, validation_data=val_generator, 
                        validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/50
# 11/11 [==============================] - ETA: 0s - loss: 1.4857 - categorical_accuracy: 0.3168
# Epoch 1: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00001-1.48570-0.31676-1.31323-0.17969.h5
# 11/11 [==============================] - 1189s 117s/step - loss: 1.4857 - categorical_accuracy: 0.3168 - val_loss: 1.3132 - val_categorical_accuracy: 0.1797 - lr: 0.0100
# Epoch 2/50
# 11/11 [==============================] - ETA: 0s - loss: 1.3598 - categorical_accuracy: 0.3381
# Epoch 2: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00002-1.35980-0.33807-1.34360-0.19531.h5
# 11/11 [==============================] - 32s 3s/step - loss: 1.3598 - categorical_accuracy: 0.3381 - val_loss: 1.3436 - val_categorical_accuracy: 0.1953 - lr: 0.0100
# Epoch 3/50
# 11/11 [==============================] - ETA: 0s - loss: 1.2573 - categorical_accuracy: 0.3892
# Epoch 3: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00003-1.25734-0.38920-1.28161-0.17969.h5
# 11/11 [==============================] - 33s 3s/step - loss: 1.2573 - categorical_accuracy: 0.3892 - val_loss: 1.2816 - val_categorical_accuracy: 0.1797 - lr: 0.0100
# Epoch 4/50
# 11/11 [==============================] - ETA: 0s - loss: 1.3239 - categorical_accuracy: 0.3537
# Epoch 4: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00004-1.32393-0.35369-1.28024-0.19531.h5
# 11/11 [==============================] - 32s 3s/step - loss: 1.3239 - categorical_accuracy: 0.3537 - val_loss: 1.2802 - val_categorical_accuracy: 0.1953 - lr: 0.0100
# Epoch 5/50
# 11/11 [==============================] - ETA: 0s - loss: 1.2742 - categorical_accuracy: 0.3991
# Epoch 5: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00005-1.27418-0.39915-1.30087-0.13281.h5
# 11/11 [==============================] - 33s 3s/step - loss: 1.2742 - categorical_accuracy: 0.3991 - val_loss: 1.3009 - val_categorical_accuracy: 0.1328 - lr: 0.0100
# Epoch 6/50
# 11/11 [==============================] - ETA: 0s - loss: 1.2784 - categorical_accuracy: 0.3892
# Epoch 6: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00006-1.27844-0.38920-1.20727-0.21094.h5
# 11/11 [==============================] - 32s 3s/step - loss: 1.2784 - categorical_accuracy: 0.3892 - val_loss: 1.2073 - val_categorical_accuracy: 0.2109 - lr: 0.0100
# Epoch 7/50
# 11/11 [==============================] - ETA: 0s - loss: 1.3315 - categorical_accuracy: 0.4034
# Epoch 7: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00007-1.33150-0.40341-1.27671-0.13281.h5
# 11/11 [==============================] - 33s 3s/step - loss: 1.3315 - categorical_accuracy: 0.4034 - val_loss: 1.2767 - val_categorical_accuracy: 0.1328 - lr: 0.0100
# Epoch 8/50
# 11/11 [==============================] - ETA: 0s - loss: 1.3490 - categorical_accuracy: 0.4134
# Epoch 8: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00008-1.34898-0.41335-1.24591-0.23438.h5
# 11/11 [==============================] - 32s 3s/step - loss: 1.3490 - categorical_accuracy: 0.4134 - val_loss: 1.2459 - val_categorical_accuracy: 0.2344 - lr: 0.0100
# Epoch 9/50
# 11/11 [==============================] - ETA: 0s - loss: 1.4010 - categorical_accuracy: 0.3423
# Epoch 9: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00009-1.40097-0.34233-1.33248-0.16406.h5
# 11/11 [==============================] - 33s 3s/step - loss: 1.4010 - categorical_accuracy: 0.3423 - val_loss: 1.3325 - val_categorical_accuracy: 0.1641 - lr: 0.0100
# Epoch 10/50
# 11/11 [==============================] - ETA: 0s - loss: 1.4907 - categorical_accuracy: 0.3395
# Epoch 10: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00010-1.49069-0.33949-1.42025-0.11719.h5
# 11/11 [==============================] - 32s 3s/step - loss: 1.4907 - categorical_accuracy: 0.3395 - val_loss: 1.4203 - val_categorical_accuracy: 0.1172 - lr: 0.0100
# Epoch 11/50
# 11/11 [==============================] - ETA: 0s - loss: 1.5628 - categorical_accuracy: 0.3168
# Epoch 11: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00011-1.56285-0.31676-1.52036-0.18750.h5
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
# 11/11 [==============================] - 33s 3s/step - loss: 1.5628 - categorical_accuracy: 0.3168 - val_loss: 1.5204 - val_categorical_accuracy: 0.1875 - lr: 0.0100
# Epoch 12/50
# 11/11 [==============================] - ETA: 0s - loss: 1.5288 - categorical_accuracy: 0.3196
# Epoch 12: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00012-1.52876-0.31960-1.62381-0.17188.h5
# 11/11 [==============================] - 32s 3s/step - loss: 1.5288 - categorical_accuracy: 0.3196 - val_loss: 1.6238 - val_categorical_accuracy: 0.1719 - lr: 0.0020
# Epoch 13/50
# 11/11 [==============================] - ETA: 0s - loss: 1.3970 - categorical_accuracy: 0.3381
# Epoch 13: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00013-1.39703-0.33807-1.58625-0.18750.h5
# 11/11 [==============================] - 33s 3s/step - loss: 1.3970 - categorical_accuracy: 0.3381 - val_loss: 1.5863 - val_categorical_accuracy: 0.1875 - lr: 0.0020
# Epoch 14/50
# 11/11 [==============================] - ETA: 0s - loss: 1.3791 - categorical_accuracy: 0.3821
# Epoch 14: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00014-1.37905-0.38210-1.56768-0.19531.h5
# 11/11 [==============================] - 32s 3s/step - loss: 1.3791 - categorical_accuracy: 0.3821 - val_loss: 1.5677 - val_categorical_accuracy: 0.1953 - lr: 0.0020
# Epoch 15/50
# 11/11 [==============================] - ETA: 0s - loss: 1.2782 - categorical_accuracy: 0.3551
# Epoch 15: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00015-1.27816-0.35511-1.48342-0.15625.h5
# 11/11 [==============================] - 33s 3s/step - loss: 1.2782 - categorical_accuracy: 0.3551 - val_loss: 1.4834 - val_categorical_accuracy: 0.1562 - lr: 0.0020
# Epoch 16/50
# 11/11 [==============================] - ETA: 0s - loss: 1.2223 - categorical_accuracy: 0.4091
# Epoch 16: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00016-1.22233-0.40909-1.45971-0.17188.h5
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.001.
# 11/11 [==============================] - 31s 3s/step - loss: 1.2223 - categorical_accuracy: 0.4091 - val_loss: 1.4597 - val_categorical_accuracy: 0.1719 - lr: 0.0020
# Epoch 17/50
# 11/11 [==============================] - ETA: 0s - loss: 1.2358 - categorical_accuracy: 0.4091
# Epoch 17: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00017-1.23581-0.40909-1.49249-0.16406.h5
# 11/11 [==============================] - 33s 3s/step - loss: 1.2358 - categorical_accuracy: 0.4091 - val_loss: 1.4925 - val_categorical_accuracy: 0.1641 - lr: 0.0010
# Epoch 18/50
# 11/11 [==============================] - ETA: 0s - loss: 1.1932 - categorical_accuracy: 0.4048
# Epoch 18: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00018-1.19319-0.40483-1.36863-0.14844.h5
# 11/11 [==============================] - 32s 3s/step - loss: 1.1932 - categorical_accuracy: 0.4048 - val_loss: 1.3686 - val_categorical_accuracy: 0.1484 - lr: 0.0010
# Epoch 19/50
# 11/11 [==============================] - ETA: 0s - loss: 1.1616 - categorical_accuracy: 0.4318
# Epoch 19: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00019-1.16160-0.43182-1.41043-0.14062.h5
# 11/11 [==============================] - 34s 3s/step - loss: 1.1616 - categorical_accuracy: 0.4318 - val_loss: 1.4104 - val_categorical_accuracy: 0.1406 - lr: 0.0010
# Epoch 20/50
# 11/11 [==============================] - ETA: 0s - loss: 1.1659 - categorical_accuracy: 0.4517
# Epoch 20: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00020-1.16586-0.45170-1.38151-0.16406.h5
# 11/11 [==============================] - 32s 3s/step - loss: 1.1659 - categorical_accuracy: 0.4517 - val_loss: 1.3815 - val_categorical_accuracy: 0.1641 - lr: 0.0010
# Epoch 21/50
# 11/11 [==============================] - ETA: 0s - loss: 1.1484 - categorical_accuracy: 0.4318
# Epoch 21: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00021-1.14842-0.43182-1.36499-0.15625.h5
# 11/11 [==============================] - 33s 3s/step - loss: 1.1484 - categorical_accuracy: 0.4318 - val_loss: 1.3650 - val_categorical_accuracy: 0.1562 - lr: 0.0010
# Epoch 22/50
# 11/11 [==============================] - ETA: 0s - loss: 1.1528 - categorical_accuracy: 0.4446
# Epoch 22: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00022-1.15283-0.44460-1.39275-0.18750.h5
# 11/11 [==============================] - 32s 3s/step - loss: 1.1528 - categorical_accuracy: 0.4446 - val_loss: 1.3927 - val_categorical_accuracy: 0.1875 - lr: 0.0010
# Epoch 23/50
# 11/11 [==============================] - ETA: 0s - loss: 1.1471 - categorical_accuracy: 0.4389
# Epoch 23: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00023-1.14714-0.43892-1.43362-0.15625.h5
# 11/11 [==============================] - 33s 3s/step - loss: 1.1471 - categorical_accuracy: 0.4389 - val_loss: 1.4336 - val_categorical_accuracy: 0.1562 - lr: 0.0010
# Epoch 24/50
# 11/11 [==============================] - ETA: 0s - loss: 1.1316 - categorical_accuracy: 0.4517
# Epoch 24: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00024-1.13163-0.45170-1.48641-0.14062.h5
# 11/11 [==============================] - 32s 3s/step - loss: 1.1316 - categorical_accuracy: 0.4517 - val_loss: 1.4864 - val_categorical_accuracy: 0.1406 - lr: 0.0010
# Epoch 25/50
# 11/11 [==============================] - ETA: 0s - loss: 1.1231 - categorical_accuracy: 0.4616
# Epoch 25: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00025-1.12309-0.46165-1.44954-0.15625.h5
# 11/11 [==============================] - 33s 3s/step - loss: 1.1231 - categorical_accuracy: 0.4616 - val_loss: 1.4495 - val_categorical_accuracy: 0.1562 - lr: 0.0010
# Epoch 26/50
# 11/11 [==============================] - ETA: 0s - loss: 1.1190 - categorical_accuracy: 0.4716
# Epoch 26: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00026-1.11904-0.47159-1.31112-0.18750.h5
# 11/11 [==============================] - 32s 3s/step - loss: 1.1190 - categorical_accuracy: 0.4716 - val_loss: 1.3111 - val_categorical_accuracy: 0.1875 - lr: 0.0010
# Epoch 27/50
# 11/11 [==============================] - ETA: 0s - loss: 1.0937 - categorical_accuracy: 0.4759
# Epoch 27: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00027-1.09367-0.47585-1.42939-0.17188.h5
# 11/11 [==============================] - 32s 3s/step - loss: 1.0937 - categorical_accuracy: 0.4759 - val_loss: 1.4294 - val_categorical_accuracy: 0.1719 - lr: 0.0010
# Epoch 28/50
# 11/11 [==============================] - ETA: 0s - loss: 1.1110 - categorical_accuracy: 0.4659
# Epoch 28: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00028-1.11105-0.46591-1.60842-0.15625.h5
# 11/11 [==============================] - 32s 3s/step - loss: 1.1110 - categorical_accuracy: 0.4659 - val_loss: 1.6084 - val_categorical_accuracy: 0.1562 - lr: 0.0010
# Epoch 29/50
# 11/11 [==============================] - ETA: 0s - loss: 1.1022 - categorical_accuracy: 0.4730
# Epoch 29: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00029-1.10219-0.47301-1.37122-0.17969.h5
# 11/11 [==============================] - 33s 3s/step - loss: 1.1022 - categorical_accuracy: 0.4730 - val_loss: 1.3712 - val_categorical_accuracy: 0.1797 - lr: 0.0010
# Epoch 30/50
# 11/11 [==============================] - ETA: 0s - loss: 1.0994 - categorical_accuracy: 0.4801
# Epoch 30: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00030-1.09944-0.48011-1.54436-0.14844.h5
# 11/11 [==============================] - 32s 3s/step - loss: 1.0994 - categorical_accuracy: 0.4801 - val_loss: 1.5444 - val_categorical_accuracy: 0.1484 - lr: 0.0010
# Epoch 31/50
# 11/11 [==============================] - ETA: 0s - loss: 1.0982 - categorical_accuracy: 0.4716
# Epoch 31: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00031-1.09822-0.47159-1.26094-0.17969.h5
# 11/11 [==============================] - 33s 3s/step - loss: 1.0982 - categorical_accuracy: 0.4716 - val_loss: 1.2609 - val_categorical_accuracy: 0.1797 - lr: 0.0010
# Epoch 32/50
# 11/11 [==============================] - ETA: 0s - loss: 1.0860 - categorical_accuracy: 0.4716
# Epoch 32: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00032-1.08604-0.47159-1.33478-0.18750.h5
# 11/11 [==============================] - 32s 3s/step - loss: 1.0860 - categorical_accuracy: 0.4716 - val_loss: 1.3348 - val_categorical_accuracy: 0.1875 - lr: 0.0010
# Epoch 33/50
# 11/11 [==============================] - ETA: 0s - loss: 1.0711 - categorical_accuracy: 0.4858
# Epoch 33: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00033-1.07114-0.48580-1.36968-0.20312.h5
# 11/11 [==============================] - 33s 3s/step - loss: 1.0711 - categorical_accuracy: 0.4858 - val_loss: 1.3697 - val_categorical_accuracy: 0.2031 - lr: 0.0010
# Epoch 34/50
# 11/11 [==============================] - ETA: 0s - loss: 1.0826 - categorical_accuracy: 0.4929
# Epoch 34: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00034-1.08256-0.49290-1.42168-0.14062.h5
# 11/11 [==============================] - 32s 3s/step - loss: 1.0826 - categorical_accuracy: 0.4929 - val_loss: 1.4217 - val_categorical_accuracy: 0.1406 - lr: 0.0010
# Epoch 35/50
# 11/11 [==============================] - ETA: 0s - loss: 1.0718 - categorical_accuracy: 0.4858
# Epoch 35: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00035-1.07179-0.48580-1.62775-0.17969.h5
# 11/11 [==============================] - 37s 4s/step - loss: 1.0718 - categorical_accuracy: 0.4858 - val_loss: 1.6278 - val_categorical_accuracy: 0.1797 - lr: 0.0010
# Epoch 36/50
# 11/11 [==============================] - ETA: 0s - loss: 1.0775 - categorical_accuracy: 0.4474
# Epoch 36: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00036-1.07748-0.44744-1.40318-0.17969.h5
# 11/11 [==============================] - 31s 3s/step - loss: 1.0775 - categorical_accuracy: 0.4474 - val_loss: 1.4032 - val_categorical_accuracy: 0.1797 - lr: 0.0010
# Epoch 37/50
# 11/11 [==============================] - ETA: 0s - loss: 1.0678 - categorical_accuracy: 0.4688
# Epoch 37: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00037-1.06782-0.46875-1.27572-0.17969.h5
# 11/11 [==============================] - 32s 3s/step - loss: 1.0678 - categorical_accuracy: 0.4688 - val_loss: 1.2757 - val_categorical_accuracy: 0.1797 - lr: 0.0010
# Epoch 38/50
# 11/11 [==============================] - ETA: 0s - loss: 1.0647 - categorical_accuracy: 0.4830
# Epoch 38: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00038-1.06469-0.48295-1.21076-0.17969.h5
# 11/11 [==============================] - 32s 3s/step - loss: 1.0647 - categorical_accuracy: 0.4830 - val_loss: 1.2108 - val_categorical_accuracy: 0.1797 - lr: 0.0010
# Epoch 39/50
# 11/11 [==============================] - ETA: 0s - loss: 1.0511 - categorical_accuracy: 0.5000
# Epoch 39: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00039-1.05105-0.50000-1.18778-0.22656.h5
# 11/11 [==============================] - 33s 3s/step - loss: 1.0511 - categorical_accuracy: 0.5000 - val_loss: 1.1878 - val_categorical_accuracy: 0.2266 - lr: 0.0010
# Epoch 40/50
# 11/11 [==============================] - ETA: 0s - loss: 1.0797 - categorical_accuracy: 0.4716
# Epoch 40: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00040-1.07969-0.47159-1.28171-0.42188.h5
# 11/11 [==============================] - 31s 3s/step - loss: 1.0797 - categorical_accuracy: 0.4716 - val_loss: 1.2817 - val_categorical_accuracy: 0.4219 - lr: 0.0010
# Epoch 41/50
# 11/11 [==============================] - ETA: 0s - loss: 1.0648 - categorical_accuracy: 0.4830
# Epoch 41: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00041-1.06477-0.48295-1.22765-0.40625.h5
# 11/11 [==============================] - 32s 3s/step - loss: 1.0648 - categorical_accuracy: 0.4830 - val_loss: 1.2277 - val_categorical_accuracy: 0.4062 - lr: 0.0010
# Epoch 42/50
# 11/11 [==============================] - ETA: 0s - loss: 1.0540 - categorical_accuracy: 0.4872
# Epoch 42: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00042-1.05399-0.48722-1.20021-0.20312.h5
# 11/11 [==============================] - 31s 3s/step - loss: 1.0540 - categorical_accuracy: 0.4872 - val_loss: 1.2002 - val_categorical_accuracy: 0.2031 - lr: 0.0010
# Epoch 43/50
# 11/11 [==============================] - ETA: 0s - loss: 1.0314 - categorical_accuracy: 0.5071
# Epoch 43: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00043-1.03136-0.50710-1.23638-0.42969.h5
# 11/11 [==============================] - 33s 3s/step - loss: 1.0314 - categorical_accuracy: 0.5071 - val_loss: 1.2364 - val_categorical_accuracy: 0.4297 - lr: 0.0010
# Epoch 44/50
# 11/11 [==============================] - ETA: 0s - loss: 1.0416 - categorical_accuracy: 0.4943
# Epoch 44: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00044-1.04156-0.49432-1.38592-0.45312.h5
# 11/11 [==============================] - 32s 3s/step - loss: 1.0416 - categorical_accuracy: 0.4943 - val_loss: 1.3859 - val_categorical_accuracy: 0.4531 - lr: 0.0010
# Epoch 45/50
# 11/11 [==============================] - ETA: 0s - loss: 1.0506 - categorical_accuracy: 0.5014
# Epoch 45: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00045-1.05057-0.50142-1.18441-0.41406.h5
# 11/11 [==============================] - 32s 3s/step - loss: 1.0506 - categorical_accuracy: 0.5014 - val_loss: 1.1844 - val_categorical_accuracy: 0.4141 - lr: 0.0010
# Epoch 46/50
# 11/11 [==============================] - ETA: 0s - loss: 1.0447 - categorical_accuracy: 0.4957
# Epoch 46: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00046-1.04471-0.49574-1.41974-0.40625.h5
# 11/11 [==============================] - 32s 3s/step - loss: 1.0447 - categorical_accuracy: 0.4957 - val_loss: 1.4197 - val_categorical_accuracy: 0.4062 - lr: 0.0010
# Epoch 47/50
# 11/11 [==============================] - ETA: 0s - loss: 1.0422 - categorical_accuracy: 0.5099
# Epoch 47: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00047-1.04222-0.50994-1.18555-0.46094.h5
# 11/11 [==============================] - 33s 3s/step - loss: 1.0422 - categorical_accuracy: 0.5099 - val_loss: 1.1855 - val_categorical_accuracy: 0.4609 - lr: 0.0010
# Epoch 48/50
# 11/11 [==============================] - ETA: 0s - loss: 1.0297 - categorical_accuracy: 0.5327
# Epoch 48: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00048-1.02973-0.53267-1.63114-0.36719.h5
# 11/11 [==============================] - 32s 3s/step - loss: 1.0297 - categorical_accuracy: 0.5327 - val_loss: 1.6311 - val_categorical_accuracy: 0.3672 - lr: 0.0010
# Epoch 49/50
# 11/11 [==============================] - ETA: 0s - loss: 1.0186 - categorical_accuracy: 0.5028
# Epoch 49: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00049-1.01860-0.50284-1.16025-0.46094.h5
# 11/11 [==============================] - 32s 3s/step - loss: 1.0186 - categorical_accuracy: 0.5028 - val_loss: 1.1602 - val_categorical_accuracy: 0.4609 - lr: 0.0010
# Epoch 50/50
# 11/11 [==============================] - ETA: 0s - loss: 1.0045 - categorical_accuracy: 0.5185
# Epoch 50: saving model to model_init_exp_16_2023-05-2607_41_20.415256/model-00050-1.00448-0.51847-1.21097-0.40625.h5
# 11/11 [==============================] - 32s 3s/step - loss: 1.0045 - categorical_accuracy: 0.5185 - val_loss: 1.2110 - val_categorical_accuracy: 0.4062 - lr: 0.0010

# %%
model.save('/content/drive/MyDrive/Project_data/model.h5')

# %%
plt.figure(figsize=(20,6))
ax1 = plt.subplot(121)
ax1 = plt.plot(history.history['loss'])
ax1 = plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower left')
ax2 = plt.subplot(122)
ax2 = plt.plot(history.history['categorical_accuracy'])
ax2 = plt.plot(history.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('categorical_accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower left')
